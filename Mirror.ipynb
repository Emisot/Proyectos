# %%
from PIL import Image

# %%
Image.open('aguila.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1054x1235 at 0x7F60A3D1FC10>

# %%
img=Image.open('aguila.jpg')
Mirror_Image=img.transpose(Image.FLIP_LEFT_RIGHT)
Mirror_Image.save(r'aguila_mirror.png')
Image.open('aguila_mirror.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1054x1235 at 0x7F60A3BE5910>
